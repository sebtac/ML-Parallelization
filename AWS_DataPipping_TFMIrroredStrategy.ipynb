# %%
pip install sagemaker

# %%
# SEBTAC's FINDINGs

OBJECTIVE:
    - DISTRIBUTED TENSORFLOW on AWS
    - DISTRIBUTED INPUT AND TRAINING
    - DATA INPUT MODES: "Pipe", "File", "FastFile"
    - TRAIN PARALLELIZATION APPROACH: "TF - Mirrored Strategy", "SMD - Sage Maker Distributed", "MPI"
    - DATA PARALLELIZATION APPROACH: data sharding (4 and 120 Shards)
    - DATA SOURCE: S3, FSX for Lustre

BEST:
    - with "MPI"
    - 8 GPUs x 1 Instance
    - 120 shards on input,
    - "FastFile",
    - "ShardedByS3Key" -- although small difference from "FullyReplicated"
    - with bigger datasets, there should be potential for "FSX for Lustre"
    
FINDINGS:
    - Earlier tests showed benefit of training on GPUs over CPUs
    - Training on 8 GPU instances speeds up training 4x over 1 GPU instance. Other tests sugest speeds up in range of 6x thus:
        NEXT STEP: test if the 4x speedup is just a result of a stronger GPU instance and the traiing happens on only 1 GPU out of 8 available on the EC2 Instance 
    - FSX for Lustre... slows down training
        - it might be due to small file sizes
            - NEXT STEP - test FSX for Lustre with larger files
    - DATA SHARDS
        - 120 Shards better then 4 Shard
            - training times comperable
            - the fit higher with training onthe same amount of data and within the same time
                - potentially, sharding offers additional layer of randomized sampling which has positive impact on training
            - this does not mean that increasing nnumber of shards indifinatively will improve training!!!
                - we will loose benefits of batching and incrrease communication and control overhead
    - "FAST FILE" has advantege over "FILE" and "PIPE" modes
    - "FullyReplicated" has advantage over "ShardedByS3Key" #(distribution = )
        - Small Input File size allows to load complete data on the instance and speed up initialization 
    - "SMD" 
        - Slowest!
        - Failed with mulit-instsance setup
    - "MPI" 
        - Fastest!
        - Works with Multi-Instance setup!!!

# %%
##################################
### "FastFile", "Pipe", "File" ###
##################################

import sagemaker
from sagemaker import get_execution_role
from sagemaker.tensorflow import TensorFlow

hyperparameters = {"input_dist_mode": "Pipe", #"FastFile", "Pipe", "File"
                   "shards_on_input": 120, # 4, 120 (put proper shards in shard-specific subfolders in S3 first!)
                   "epochs": 3, # 3: Standard Tests, 25: With Early Stopping
                   "download_raw_data": 1, # ShouLd we create TFRECORD files with MINIST data?
                   "train_dist_mode": "TF", # "TF", "SMD", "MPI"
                  }

train_input = sagemaker.inputs.TrainingInput("s3://mnist-tdrecords/train/{}".format(hyperparameters["shards_on_input"]),  
                                             input_mode = hyperparameters["input_dist_mode"],
                                             distribution = 'ShardedByS3Key' #'ShardedByS3Key', 'FullyReplicated'
                                            )

tf_estimator = TensorFlow(entry_point = "AWS_DataPipping_TFMirroredStrategy.py",
                          source_dir = "./",
                          framework_version = "2.3",
                          py_version = "py37",
                          instance_type = "ml.p3.2xlarge", # "ml.p3.2xlarge", "ml.p3.8xlarge", "ml.p3.16xlarge"
                          instance_count = 1,
                          role = sagemaker.get_execution_role(),
                          hyperparameters = hyperparameters,
                          output_path = f"s3://mnist-tdrecords/output",
                          input_mode = hyperparameters["input_dist_mode"], # "File", "Pipe", "FastFile")
                         )

s3_data_channels = {"train": train_input}
#s3_data_channels = {"train": "s3://mnist-tdrecords/train/{}".format(hyperparameters["shards_on_input"])}
                    #"validation": f"s3://{bucket_name}/data/validation",}

tf_estimator.fit(s3_data_channels)

##################################################################################################################################################################################
######## IF SUDDENLY NO TRAINING HAPPENS OR IT DOES VERY QUICKLY DELETE THE RESULTS OF THE PREVIOUS RUNS AS LIST_OBJECTS FUNCTION HAS A LIMIT ON THE LENGTH OF THE OUTPUT ########
##################################################################################################################################################################################

# %%
print(train_input)

# %%
# PIPE MODE
1 GPU, 4 shards on input, FullyReplicated
Epoch 3, Loss: 0.09680283069610596, Train Accuracy: 96.4366683959961, Test Accuracy: 0.0
TIME 279.08890867233276

1 GPU, 120 shards on input, FullyReplicated
Epoch 3, Loss: 0.004249399993568659, Train Accuracy: 99.88666534423828, Test Accuracy: 0.0
TIME 278.04257345199585

1 GPU, 120 shards on input, ShardedByS3Key
Epoch 3, Loss: 0.0002816336345858872, Train Accuracy: 99.99166870117188, Test Accuracy: 77.75
TIME 288.7442648410797

8 GPU, 4 shards on input, FullyReplicated
Epoch 3, Loss: 0.35395368933677673, Train Accuracy: 86.75333404541016, Test Accuracy: 0.0
TIME 71.81656908988953

8 GPU, 120 shards on input, FullyReplicated
Epoch 3, Loss: 0.0014360351487994194, Train Accuracy: 99.98833465576172, Test Accuracy: 0.0
TIME 72.16402530670166

8 GPU, 120 shards on input, ShardedByS3Key
Epoch 3, Loss: 0.003127657575532794, Train Accuracy: 99.9766616821289, Test Accuracy: 77.45000457763672
TIME 75.63692235946655

# %%
# FastFile

1 GPU, 4 shards on input, FullyReplicated
Epoch 3, Loss: 0.10208243876695633, Train Accuracy: 96.2316665649414, Test Accuracy: 0.0
TIME 275.73823285102844

1 GPU, 120 shards on input, FullyReplicated
Epoch 3, Loss: 0.007705101743340492, Train Accuracy: 99.80166625976562, Test Accuracy: 0.0
TIME 277.03554940223694

8 GPU, 4 shards on input, FullyReplicated
Epoch 3, Loss: 0.46059784293174744, Train Accuracy: 82.9566650390625, Test Accuracy: 0.0
TIME 68.45022320747375

8 GPU, 120 shards on input, FullyReplicated
Epoch 3, Loss: 0.04005113244056702, Train Accuracy: 98.80333709716797, Test Accuracy: 0.0
TIME 68.02924108505249

8 GPU, 120 shards on input, ShardedByS3Key
Epoch 3, Loss: 0.11077616363763809, Train Accuracy: 96.31666564941406, Test Accuracy: 0.0
TIME 68.31658935546875

# %%
##################################
######### FSX for Lustre #########
##################################

hyperparameters = {"input_dist_mode": "File", #"FastFile", "Pipe", "File" -- FOR FSx "File" ONLY!!!
                   "shards_on_input": 120, # 4, 120 -- Shards in S3
                   "epochs": 25, # 3: Standard Tests, 25: With Early Stopping
                   "download_raw_data": 1, # ShouLd we create TFRECORD files with MINIST data?
                   "train_dist_mode": "TF", # "TF", "SMD", "MPI"
                  }

from sagemaker.debugger import ProfilerConfig, FrameworkProfile

profiler_config = ProfilerConfig(framework_profile_params=FrameworkProfile(start_step=2, num_steps=7))

from sagemaker.inputs import FileSystemInput

# Specify file system id.
file_system_id = "fs-061783acdcbd8da72"

# Specify directory path associated with the file system. You need to provide normalized and absolute path here.
file_system_directory_path = "/gllyrbev/Train_{}_Shards".format(hyperparameters["shards_on_input"])
    
# Specify the access mode of the mount of the directory associated with the file system.
# Directory can be mounted either in 'ro'(read-only) or 'rw' (read-write).
file_system_access_mode = "rw"

# Specify your file system type, "EFS" or "FSxLustre".
file_system_type = "FSxLustre"

# Give Amazon SageMaker Training Jobs Access to FileSystem Resources in Your Amazon VPC.
security_groups_ids = ["sg-36929710"]
subnets = ["subnet-006ebd66"]

fs_train_input = FileSystemInput(file_system_id=file_system_id,
                                 file_system_type=file_system_type,
                                 directory_path=file_system_directory_path,
                                 file_system_access_mode=file_system_access_mode)

import sagemaker
from sagemaker import get_execution_role
from sagemaker.tensorflow import TensorFlow

train_input = sagemaker.inputs.TrainingInput("s3://mnist-tdrecords/train/{}".format(hyperparameters["shards_on_input"]),  
                                             input_mode = hyperparameters["input_dist_mode"],
                                             distribution = 'FullyReplicated' #'ShardedByS3Key', 'FullyReplicated'
                                            )

tf_estimator = TensorFlow(entry_point = "AWS_DataPipping_TFMirroredStrategy.py",
                          source_dir = "./",
                          framework_version = "2.3",
                          py_version = "py37",
                          instance_type = "ml.p3.16xlarge", # "ml.p3.2xlarge", "ml.p3.8xlarge", "ml.p3.16xlarge"
                          instance_count = 1,
                          role = sagemaker.get_execution_role(),
                          subnets=subnets,
                          security_group_ids=security_groups_ids,
                          hyperparameters = hyperparameters,
                          output_path = f"s3://mnist-tdrecords/output",                          
                          input_mode = hyperparameters["input_dist_mode"], # "File", "Pipe", "FastFile")
                          profiler_config=profiler_config,
                         )

s3_data_channels = {"train": fs_train_input}
#s3_data_channels = {"train": "s3://mnist-tdrecords/train/{}".format(hyperparameters["shards_on_input"])}
                    #"validation": f"s3://{bucket_name}/data/validation",}

tf_estimator.fit(s3_data_channels)

# %%
# FSx for LUSTRE

1 GPU, 4 shards on input, FullyReplicated
Epoch 3, Loss: 0.10235357284545898, Train Accuracy: 96.22332763671875, Test Accuracy: 0.0
TIME 285.3839440345764

1 GPU, 120 shards on input, FullyReplicated
Epoch 3, Loss: 0.0075263879261910915, Train Accuracy: 99.82499694824219, Test Accuracy: 0.0
TIME 282.914315700531

8 GPU, 4 shards on input, FullyReplicated
Epoch 3, Loss: 0.47831735014915466, Train Accuracy: 82.04833221435547, Test Accuracy: 0.0
TIME 121.28670692443848

8 GPU, 120 shards on input, FullyReplicated
Epoch 3, Loss: 0.017312103882431984, Train Accuracy: 99.54166412353516, Test Accuracy: 0.0
TIME 119.6302547454834

# %%
###################################
####### SM_Distirbuted, MPI #######
###################################

import sagemaker
from sagemaker import get_execution_role
from sagemaker.tensorflow import TensorFlow

hyperparameters = {"input_dist_mode": "FastFile", #"FastFile", "Pipe", "File"
                   "shards_on_input": 120, # 4, 120 (for inbetween created subfolders in S3 first
                   "train_dist_mode": "MPI", #"TF", "SMD", "MPI"
                   "epochs": 3, # 3: Standard Tests, 25: With Early Stopping
                   "download_raw_data": 1, # ShouLd we create TFRECORD files with MINIST data?
                  }

train_input = sagemaker.inputs.TrainingInput("s3://mnist-tdrecords/train/{}".format(hyperparameters["shards_on_input"]),  
                                             input_mode = hyperparameters["input_dist_mode"],
                                             distribution = 'FullyReplicated' #'ShardedByS3Key', 'FullyReplicated'
                                            )

# Training using SMDataParallel Distributed Training Framework

if hyperparameters["train_dist_mode"] == "MPI": # @AWS SaagMaker: MPI==HOROVOD!!!
    distribution = {"mpi": {"enabled": True,
                            "processes_per_host": 8,
                            'custom_mpi_options': '-verbose --NCCL_DEBUG=INFO -x OMPI_MCA_btl_vader_single_copy_mechanism=none'}}

elif hyperparameters["train_dist_mode"] == "SMD":
    distribution={"smdistributed": {"dataparallel": {"enabled": True,}}}
    
# SMD as is runs 8 processes on each instance
# Also works with #"processes_per_host": 1,}}} and 8 processes per insrtance are executed too.
# with "processes_per_host": 8 errors pop up - probabaly due to multiple processes being executed on each GPU
# with MPI the error is realted to the fact that code in the .py file uses smdistributed which creates conflict with MPI

tf_estimator = TensorFlow(entry_point = "AWS_DataPipping_TFMirroredStrategy.py",
                          source_dir = "./",
                          framework_version = "2.3",
                          py_version = "py37",
                          instance_type = "ml.p3.16xlarge", # "ml.p3.2xlarge", "ml.p3.8xlarge", "ml.p3.16xlarge", "local_gpu"
                          instance_count = 1, # 2+ DOES NOT WORK ??!?!?!?!?
                          role = sagemaker.get_execution_role(),
                          hyperparameters = hyperparameters,
                          output_path = f"s3://mnist-tdrecords/output",
                          input_mode = hyperparameters["input_dist_mode"], # "File", "Pipe", "FastFile")
                          distribution = distribution,
                         )

s3_data_channels = {"train": train_input}
#s3_data_channels = {"train": "s3://mnist-tdrecords/train/{}".format(hyperparameters["shards_on_input"])}
                    #"validation": f"s3://{bucket_name}/data/validation",}

tf_estimator.fit(s3_data_channels)

##########################################################################################################################
######## IF SUDDENLY NO TRAINING HAPPENS OR IT DOES VERY QUICKLY, ######################################################## 
######## DELETE THE RESULTS OF THE PREVIOUS RUNS AS LIST_OBJECTS FUNCTION HAS A LIMIT ON THE LENGTH OF THE OUTPUT ########
##########################################################################################################################
# Out:
# INFO:sagemaker.image_uris:image_uri is not presented, retrieving image_uri based on instance_type, framework etc.
# INFO:sagemaker.image_uris:image_uri is not presented, retrieving image_uri based on instance_type, framework etc.
# Using provided s3_resource
# INFO:sagemaker:Creating training-job with name: tensorflow-training-2023-05-17-14-49-51-884
# 2023-05-17 14:49:52 Starting - Starting the training job......
# 2023-05-17 14:50:48 Starting - Preparing the instances for training.........
# 2023-05-17 14:52:06 Downloading - Downloading input data...
# 2023-05-17 14:52:26 Training - Downloading the training image.........
# 2023-05-17 14:53:57 Training - Training image download completed. Training in progress..2023-05-17 14:54:26.923652: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2023-05-17 14:54:26.923855: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# 2023-05-17 14:54:26.931398: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.2
# 2023-05-17 14:54:26.970428: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2023-05-17 14:54:28,545 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2023-05-17 14:54:28,990 sagemaker-training-toolkit INFO     Starting MPI run as worker node.
# 2023-05-17 14:54:28,990 sagemaker-training-toolkit INFO     Creating SSH daemon.
# 2023-05-17 14:54:28,996 sagemaker-training-toolkit INFO     Waiting for MPI workers to establish their SSH connections
# 2023-05-17 14:54:28,996 sagemaker-training-toolkit INFO     Env Hosts: ['algo-1'] Hosts: ['algo-1:8'] process_per_hosts: 8 num_processes: 8
# 2023-05-17 14:54:28,998 sagemaker-training-toolkit INFO     Network interface name: eth0
# 2023-05-17 14:54:29,082 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {
#         "sagemaker_mpi_custom_mpi_options": "-verbose --NCCL_DEBUG=INFO -x OMPI_MCA_btl_vader_single_copy_mechanism=none",
#         "sagemaker_mpi_enabled": true,
#         "sagemaker_mpi_num_of_processes_per_host": 8
#     },
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "download_raw_data": 1,
#         "epochs": 3,
#         "input_dist_mode": "Pipe",
#         "model_dir": "/opt/ml/model",
#         "shards_on_input": 120,
#         "train_dist_mode": "MPI"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "Pipe",
#             "S3DistributionType": "ShardedByS3Key",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "tensorflow-training-2023-05-17-14-49-51-884",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://mnist-tdrecords/tensorflow-training-2023-05-17-14-49-51-884/source/sourcedir.tar.gz",
#     "module_name": "AWS_DataPipping_TFMirroredStrategy",
#     "network_interface_name": "eth0",
#     "num_cpus": 64,
#     "num_gpus": 8,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.p3.16xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.p3.16xlarge",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "AWS_DataPipping_TFMirroredStrategy.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"download_raw_data":1,"epochs":3,"input_dist_mode":"Pipe","model_dir":"/opt/ml/model","shards_on_input":120,"train_dist_mode":"MPI"}
# SM_USER_ENTRY_POINT=AWS_DataPipping_TFMirroredStrategy.py
# SM_FRAMEWORK_PARAMS={"sagemaker_mpi_custom_mpi_options":"-verbose --NCCL_DEBUG=INFO -x OMPI_MCA_btl_vader_single_copy_mechanism=none","sagemaker_mpi_enabled":true,"sagemaker_mpi_num_of_processes_per_host":8}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.p3.16xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.p3.16xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"ShardedByS3Key","TrainingInputMode":"Pipe"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=AWS_DataPipping_TFMirroredStrategy
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=64
# SM_NUM_GPUS=8
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://mnist-tdrecords/tensorflow-training-2023-05-17-14-49-51-884/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_mpi_custom_mpi_options":"-verbose --NCCL_DEBUG=INFO -x OMPI_MCA_btl_vader_single_copy_mechanism=none","sagemaker_mpi_enabled":true,"sagemaker_mpi_num_of_processes_per_host":8},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"download_raw_data":1,"epochs":3,"input_dist_mode":"Pipe","model_dir":"/opt/ml/model","shards_on_input":120,"train_dist_mode":"MPI"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"ShardedByS3Key","TrainingInputMode":"Pipe"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"tensorflow-training-2023-05-17-14-49-51-884","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://mnist-tdrecords/tensorflow-training-2023-05-17-14-49-51-884/source/sourcedir.tar.gz","module_name":"AWS_DataPipping_TFMirroredStrategy","network_interface_name":"eth0","num_cpus":64,"num_gpus":8,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.p3.16xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.p3.16xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"AWS_DataPipping_TFMirroredStrategy.py"}
# SM_USER_ARGS=["--download_raw_data","1","--epochs","3","--input_dist_mode","Pipe","--model_dir","/opt/ml/model","--shards_on_input","120","--train_dist_mode","MPI"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_DOWNLOAD_RAW_DATA=1
# SM_HP_EPOCHS=3
# SM_HP_INPUT_DIST_MODE=Pipe
# SM_HP_MODEL_DIR=/opt/ml/model
# SM_HP_SHARDS_ON_INPUT=120
# SM_HP_TRAIN_DIST_MODE=MPI
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python37.zip:/usr/local/lib/python3.7:/usr/local/lib/python3.7/lib-dynload:/usr/local/lib/python3.7/site-packages
# Invoking script with the following command:
# mpirun --host algo-1:8 -np 8 --allow-run-as-root --display-map --tag-output -mca btl_tcp_if_include eth0 -mca oob_tcp_if_include eth0 -mca plm_rsh_no_tree_spawn 1 -bind-to none -map-by slot -mca pml ob1 -mca btl ^openib -mca orte_abort_on_non_zero_status 1 -mca btl_vader_single_copy_mechanism none -x NCCL_MIN_NRINGS=4 -x NCCL_SOCKET_IFNAME=eth0 -x NCCL_DEBUG=INFO -x LD_LIBRARY_PATH -x PATH -x LD_PRELOAD=/usr/local/lib/python3.7/site-packages/gethostname.cpython-37m-x86_64-linux-gnu.so -verbose -x OMPI_MCA_btl_vader_single_copy_mechanism=none -x SM_HOSTS -x SM_NETWORK_INTERFACE_NAME -x SM_HPS -x SM_USER_ENTRY_POINT -x SM_FRAMEWORK_PARAMS -x SM_RESOURCE_CONFIG -x SM_INPUT_DATA_CONFIG -x SM_OUTPUT_DATA_DIR -x SM_CHANNELS -x SM_CURRENT_HOST -x SM_MODULE_NAME -x SM_LOG_LEVEL -x SM_FRAMEWORK_MODULE -x SM_INPUT_DIR -x SM_INPUT_CONFIG_DIR -x SM_OUTPUT_DIR -x SM_NUM_CPUS -x SM_NUM_GPUS -x SM_MODEL_DIR -x SM_MODULE_DIR -x SM_TRAINING_ENV -x SM_USER_ARGS -x SM_OUTPUT_INTERMEDIATE_DIR -x SM_CHANNEL_TRAIN -x SM_HP_DOWNLOAD_RAW_DATA -x SM_HP_EPOCHS -x SM_HP_INPUT_DIST_MODE -x SM_HP_MODEL_DIR -x SM_HP_SHARDS_ON_INPUT -x SM_HP_TRAIN_DIST_MODE -x PYTHONPATH /usr/local/bin/python3.7 -m mpi4py AWS_DataPipping_TFMirroredStrategy.py --download_raw_data 1 --epochs 3 --input_dist_mode Pipe --model_dir /opt/ml/model --shards_on_input 120 --train_dist_mode MPI
#  Data for JOB [51068,1] offset 0 Total slots allocated 8
#  ========================   JOB MAP   ========================
#  Data for node: ip-10-2-225-108#011Num slots: 8#011Max slots: 0#011Num procs: 8
#  #011Process OMPI jobid: [51068,1] App: 0 Process rank: 0 Bound: N/A
#  #011Process OMPI jobid: [51068,1] App: 0 Process rank: 1 Bound: N/A
#  #011Process OMPI jobid: [51068,1] App: 0 Process rank: 2 Bound: N/A
#  #011Process OMPI jobid: [51068,1] App: 0 Process rank: 3 Bound: N/A
#  #011Process OMPI jobid: [51068,1] App: 0 Process rank: 4 Bound: N/A
#  #011Process OMPI jobid: [51068,1] App: 0 Process rank: 5 Bound: N/A
#  #011Process OMPI jobid: [51068,1] App: 0 Process rank: 6 Bound: N/A
#  #011Process OMPI jobid: [51068,1] App: 0 Process rank: 7 Bound: N/A
#  =============================================================
# [1,7]<stdout>:7 Num GPUs: 1 [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# [1,7]<stdout>:hvd.rank 7 7
# [1,3]<stdout>:3 Num GPUs: 1 [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# [1,3]<stdout>:hvd.rank 3 3
# [1,6]<stdout>:6 Num GPUs: 1 [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# [1,6]<stdout>:hvd.rank 6[1,6]<stdout>: 6
# [1,2]<stdout>:2 Num GPUs: 1 [1,2]<stdout>:[PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# [1,2]<stdout>:hvd.rank 2[1,2]<stdout>: 2
# [1,0]<stdout>:0 Num GPUs: 1 [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# [1,0]<stdout>:hvd.rank 0 0
# [1,1]<stdout>:1 Num GPUs: 1 [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# [1,1]<stdout>:hvd.rank 1 1
# [1,5]<stdout>:5 Num GPUs: 1 [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# [1,5]<stdout>:hvd.rank 5 5
# [1,4]<stdout>:4 Num GPUs: 1 [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# [1,4]<stdout>:hvd.rank 4 4
# [1,6]<stdout>:SM_CHANNEL_TRAIN /opt/ml/input/data/train
# [1,3]<stdout>:SM_CHANNEL_TRAIN /opt/ml/input/data/train
# [1,7]<stdout>:SM_CHANNEL_TRAIN /opt/ml/input/data/train
# [1,5]<stdout>:SM_CHANNEL_TRAIN /opt/ml/input/data/train
# [1,6]<stdout>:Replica 6 Number of replicas: 8
# [1,6]<stdout>:Replica 6 GLOBAL_BATCH_SIZE 512
# [1,6]<stdout>:Replica 6 Learning Rate: 0.008
# [1,3]<stdout>:Replica 3 Number of replicas: 8
# [1,3]<stdout>:Replica 3 GLOBAL_BATCH_SIZE 512
# [1,3]<stdout>:Replica 3 Learning Rate: 0.008
# [1,7]<stdout>:Replica 7 Number of replicas: 8
# [1,7]<stdout>:Replica 7 GLOBAL_BATCH_SIZE 512
# [1,7]<stdout>:Replica 7 [1,7]<stdout>:Learning Rate: 0.008
# [1,5]<stdout>:Replica 5 Number of replicas: 8
# [1,5]<stdout>:Replica[1,5]<stdout>: 5 GLOBAL_BATCH_SIZE 512
# [1,5]<stdout>:Replica 5 [1,5]<stdout>:Learning Rate: 0.008
# [1,4]<stdout>:SM_CHANNEL_TRAIN /opt/ml/input/data/train
# [1,4]<stdout>:Replica 4 Number of replicas: 8
# [1,4]<stdout>:Replica 4 GLOBAL_BATCH_SIZE 512
# [1,4]<stdout>:Replica 4 Learning Rate: 0.008
# [1,2]<stdout>:SM_CHANNEL_TRAIN /opt/ml/input/data/train
# [1,0]<stdout>:Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# [1,1]<stdout>:SM_CHANNEL_TRAIN /opt/ml/input/data/train
# [1,2]<stdout>:Replica 2 Number of replicas: 8
# [1,2]<stdout>:Replica 2 GLOBAL_BATCH_SIZE 512
# [1,2]<stdout>:Replica 2 Learning Rate: 0.008
# [1,0]<stdout>:#015 8192/29515 [=======>......................] - ETA: 0s[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>:32768/29515 [=================================] - 0s 0us/step
# [1,0]<stdout>:Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# [1,1]<stdout>:Replica 1 Number of replicas: 8
# [1,1]<stdout>:Replica 1 GLOBAL_BATCH_SIZE 512
# [1,1]<stdout>:Replica 1 [1,1]<stdout>:Learning Rate: 0.008
# [1,0]<stdout>:#015    8192/26421880 [..............................] - ETA: 0s[1,6]<stdout>:dataset 3 [1,6]<stdout>:<BatchDataset shapes: ((None, 28, 28, 1), (None,)), types: (tf.float32, tf.uint8)>
# [1,3]<stdout>:dataset 3 [1,7]<stdout>:dataset 3 [1,3]<stdout>:<BatchDataset shapes: ((None, 28, 28, 1), (None,)), types: (tf.float32, tf.uint8)>
# [1,7]<stdout>:<BatchDataset shapes: ((None, 28, 28, 1), (None,)), types: (tf.float32, tf.uint8)>
# [1,5]<stdout>:dataset 3 [1,5]<stdout>:<BatchDataset shapes: ((None, 28, 28, 1), (None,)), types: (tf.float32, tf.uint8)>
# [1,4]<stdout>:dataset 3 [1,4]<stdout>:<BatchDataset shapes: ((None, 28, 28, 1), (None,)), types: (tf.float32, tf.uint8)>
# [1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 5046272/26421880 [====>.........................] - ETA: 0s[1,3]<stdout>:[2023-05-17 14:54:35.434 algo-1:157 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,2]<stdout>:dataset 3 [1,2]<stdout>:<BatchDataset shapes: ((None, 28, 28, 1), (None,)), types: (tf.float32, tf.uint8)>
# [1,6]<stdout>:[2023-05-17 14:54:35.436 algo-1:160 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,7]<stdout>:[2023-05-17 14:54:35.437 algo-1:161 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,5]<stdout>:[2023-05-17 14:54:35.441 algo-1:159 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,4]<stdout>:[2023-05-17 14:54:35.451 algo-1:158 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01514032896/26421880 [==============>...............] - ETA: 0s[1,1]<stdout>:dataset 3 [1,2]<stdout>:[2023-05-17 14:54:35.481 algo-1:156 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,1]<stdout>:<BatchDataset shapes: ((None, 28, 28, 1), (None,)), types: (tf.float32, tf.uint8)>
# [1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>:23478272/26421880 [=========================>....] - ETA: 0s[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01526427392/26421880 [==============================] - 0s 0us/step
# [1,0]<stdout>:Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# [1,1]<stdout>:[2023-05-17 14:54:35.539 algo-1:155 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,0]<stdout>:#0158192/5148 [===============================================] - 0s 0us/step
# [1,0]<stdout>:Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# [1,0]<stdout>:#015   8192/4422102 [..............................] - ETA: 0s[1,3]<stdout>:[2023-05-17 14:54:35.610 algo-1:157 INFO profiler_config_parser.py:102] User has disabled profiler.
# [1,6]<stdout>:[2023-05-17 14:54:35.615 algo-1:160 INFO profiler_config_parser.py:102] User has disabled profiler.
# [1,7]<stdout>:[2023-05-17 14:54:35.616 algo-1:161 INFO profiler_config_parser.py:102] User has disabled profiler.
# [1,5]<stdout>:[2023-05-17 14:54:35.617 algo-1:159 INFO profiler_config_parser.py:102] User has disabled profiler.
# [1,4]<stdout>:[2023-05-17 14:54:35.620 algo-1:158 INFO profiler_config_parser.py:102] User has disabled profiler.
# [1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0154423680/4422102 [==============================] - 0s 0us/step
# [1,2]<stdout>:[2023-05-17 14:54:35.652 algo-1:156 INFO profiler_config_parser.py:102] User has disabled profiler.
# [1,1]<stdout>:[2023-05-17 14:54:35.721 algo-1:155 INFO profiler_config_parser.py:102] User has disabled profiler.
# [1,3]<stdout>:A 60000 512 8
# [1,3]<stdout>:B 117
# [1,3]<stdout>:C 14
# [1,3]<stdout>:[2023-05-17 14:54:35.725 algo-1:157 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [1,3]<stdout>:[2023-05-17 14:54:35.725 algo-1:157 INFO hook.py:201] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [1,3]<stdout>:[2023-05-17 14:54:35.726 algo-1:157 INFO hook.py:255] Saving to /opt/ml/output/tensors
# [1,3]<stdout>:[2023-05-17 14:54:35.726 algo-1:157 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [1,3]<stdout>:[2023-05-17 14:54:35.727 algo-1:157 INFO hook.py:425] Monitoring the collections: losses, sm_metrics, metrics
# [1,4]<stdout>:A 60000[1,4]<stdout>: 512 8
# [1,4]<stdout>:B[1,4]<stdout>: 117
# [1,4]<stdout>:C[1,4]<stdout>: 14
# [1,4]<stdout>:[2023-05-17 14:54:35.728 algo-1:158 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [1,4]<stdout>:[2023-05-17 14:54:35.729 algo-1:158 INFO hook.py:201] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [1,4]<stdout>:[2023-05-17 14:54:35.730 algo-1:158 INFO hook.py:255] Saving to /opt/ml/output/tensors
# [1,4]<stdout>:[2023-05-17 14:54:35.730 algo-1:158 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [1,4]<stdout>:[2023-05-17 14:54:35.730 algo-1:158 INFO hook.py:425] Monitoring the collections: metrics, losses, sm_metrics
# [1,7]<stdout>:A 60000 512 8
# [1,7]<stdout>:B 117
# [1,7]<stdout>:C 14
# [1,3]<stdout>:[2023-05-17 14:54:35.732 algo-1:157 INFO hook.py:425] Monitoring the collections: losses, sm_metrics, metrics
# [1,7]<stdout>:[2023-05-17 14:54:35.732 algo-1:161 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [1,7]<stdout>:[2023-05-17 14:54:35.733 algo-1:161 INFO hook.py:201] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [1,7]<stdout>:[2023-05-17 14:54:35.733 algo-1:161 INFO hook.py:255] Saving to /opt/ml/output/tensors
# [1,7]<stdout>:[2023-05-17 14:54:35.733 algo-1:161 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [1,7]<stdout>:[2023-05-17 14:54:35.734 algo-1:161 INFO hook.py:425] Monitoring the collections: losses, sm_metrics, metrics
# [1,4]<stdout>:[2023-05-17 14:54:35.735 algo-1:158 INFO hook.py:425] Monitoring the collections: metrics, losses, sm_metrics
# [1,7]<stdout>:[2023-05-17 14:54:35.738 algo-1:161 INFO hook.py:425] Monitoring the collections: losses, sm_metrics, metrics
# [1,5]<stdout>:A 60000 [1,5]<stdout>:512 8
# [1,5]<stdout>:B 117
# [1,5]<stdout>:C 14
# [1,6]<stdout>:A 60000 512 8[1,6]<stdout>:
# [1,6]<stdout>:B 117
# [1,6]<stdout>:C 14
# [1,5]<stdout>:[2023-05-17 14:54:35.741 algo-1:159 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [1,5]<stdout>:[2023-05-17 14:54:35.741 algo-1:159 INFO hook.py:201] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [1,6]<stdout>:[2023-05-17 14:54:35.742 algo-1:160 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [1,5]<stdout>:[2023-05-17 14:54:35.742 algo-1:159 INFO hook.py:255] Saving to /opt/ml/output/tensors
# [1,5]<stdout>:[2023-05-17 14:54:35.742 algo-1:159 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [1,3]<stdout>:Epoch 1/3
# [1,6]<stdout>:[2023-05-17 14:54:35.743 algo-1:160 INFO hook.py:201] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [1,5]<stdout>:[2023-05-17 14:54:35.743 algo-1:159 INFO hook.py:425] Monitoring the collections: losses, sm_metrics, metrics
# [1,6]<stdout>:[2023-05-17 14:54:35.743 algo-1:160 INFO hook.py:255] Saving to /opt/ml/output/tensors
# [1,6]<stdout>:[2023-05-17 14:54:35.743 algo-1:160 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [1,6]<stdout>:[2023-05-17 14:54:35.744 algo-1:160 INFO hook.py:425] Monitoring the collections: losses, metrics, sm_metrics
# [1,4]<stdout>:Epoch 1/3
# [1,5]<stdout>:[2023-05-17 14:54:35.748 algo-1:159 INFO hook.py:425] Monitoring the collections: losses, sm_metrics, metrics
# [1,7]<stdout>:Epoch 1/3
# [1,6]<stdout>:[2023-05-17 14:54:35.749 algo-1:160 INFO hook.py:425] Monitoring the collections: losses, metrics, sm_metrics
# [1,5]<stdout>:Epoch 1/3
# [1,6]<stdout>:Epoch 1/3
# [1,2]<stdout>:A 60000 512 8
# [1,2]<stdout>:B 117
# [1,2]<stdout>:C 14
# [1,2]<stdout>:[2023-05-17 14:54:35.768 algo-1:156 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [1,2]<stdout>:[2023-05-17 14:54:35.769 algo-1:156 INFO hook.py:201] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [1,2]<stdout>:[2023-05-17 14:54:35.770 algo-1:156 INFO hook.py:255] Saving to /opt/ml/output/tensors
# [1,2]<stdout>:[2023-05-17 14:54:35.770 algo-1:156 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [1,2]<stdout>:[2023-05-17 14:54:35.770 algo-1:156 INFO hook.py:425] Monitoring the collections: metrics, sm_metrics, losses
# [1,2]<stdout>:[2023-05-17 14:54:35.775 algo-1:156 INFO hook.py:425] Monitoring the collections: metrics, sm_metrics, losses
# [1,2]<stdout>:Epoch 1/3
# [1,1]<stdout>:A 60000 512 8
# [1,1]<stdout>:B 117
# [1,1]<stdout>:C 14
# [1,1]<stdout>:[2023-05-17 14:54:35.835 algo-1:155 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [1,1]<stdout>:[2023-05-17 14:54:35.835 algo-1:155 INFO hook.py:201] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [1,1]<stdout>:[2023-05-17 14:54:35.836 algo-1:155 INFO hook.py:255] Saving to /opt/ml/output/tensors
# [1,1]<stdout>:[2023-05-17 14:54:35.836 algo-1:155 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [1,1]<stdout>:[2023-05-17 14:54:35.836 algo-1:155 INFO hook.py:425] Monitoring the collections: sm_metrics, losses, metrics
# [1,1]<stdout>:[2023-05-17 14:54:35.841 algo-1:155 INFO hook.py:425] Monitoring the collections: sm_metrics, losses, metrics
# [1,1]<stdout>:Epoch 1/3
# [1,0]<stdout>:SHAPES (60000, 28, 28, 1) (60000,)
# [1,0]<stdout>:SM_CHANNEL_TRAIN /opt/ml/input/data/train
# [1,0]<stdout>:Replica 0 Number of replicas: 8
# [1,0]<stdout>:Replica 0 GLOBAL_BATCH_SIZE 512[1,0]<stdout>:
# [1,0]<stdout>:Replica 0[1,0]<stdout>: Learning Rate: 0.008
# [1,0]<stdout>:dataset 3 [1,0]<stdout>:<BatchDataset shapes: ((None, 28, 28, 1), (None,)), types: (tf.float32, tf.uint8)>
# [1,0]<stdout>:[2023-05-17 14:54:36.401 algo-1:154 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,0]<stdout>:[2023-05-17 14:54:36.583 algo-1:154 INFO profiler_config_parser.py:102] User has disabled profiler.
# [1,0]<stdout>:A 60000 512 8
# [1,0]<stdout>:B 117
# [1,0]<stdout>:C 14
# [1,0]<stdout>:[2023-05-17 14:54:36.698 algo-1:154 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [1,0]<stdout>:[2023-05-17 14:54:36.699 algo-1:154 INFO hook.py:201] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [1,0]<stdout>:[2023-05-17 14:54:36.700 algo-1:154 INFO hook.py:255] Saving to /opt/ml/output/tensors
# [1,0]<stdout>:[2023-05-17 14:54:36.700 algo-1:154 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [1,0]<stdout>:[2023-05-17 14:54:36.700 algo-1:154 INFO hook.py:425] Monitoring the collections: sm_metrics, metrics, losses
# [1,0]<stdout>:[2023-05-17 14:54:36.705 algo-1:154 INFO hook.py:425] Monitoring the collections: sm_metrics, metrics, losses
# [1,0]<stdout>:Epoch 1/3
#
# 2023-05-17 14:54:53 Uploading - Uploading generated training model[1,1]<stderr>:2023-05-17 14:54:29.630212: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,1]<stderr>:2023-05-17 14:54:29.630455: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,0]<stderr>:2023-05-17 14:54:29.641890: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,4]<stderr>:2023-05-17 14:54:29.641890: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,6]<stderr>:2023-05-17 14:54:29.641890: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,0]<stderr>:2023-05-17 14:54:29.642095: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,4]<stderr>:2023-05-17 14:54:29.642096: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,6]<stderr>:2023-05-17 14:54:29.642098: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,2]<stderr>:2023-05-17 14:54:29.656149: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,2]<stderr>:2023-05-17 14:54:29.656341: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,7]<stderr>:2023-05-17 14:54:29.663799: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,7]<stderr>:2023-05-17 14:54:29.663957: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,1]<stderr>:2023-05-17 14:54:29.675012: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,4]<stderr>:2023-05-17 14:54:29.685470: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,6]<stderr>:2023-05-17 14:54:29.685904: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,0]<stderr>:2023-05-17 14:54:29.687362: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,2]<stderr>:2023-05-17 14:54:29.701129: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,7]<stderr>:2023-05-17 14:54:29.705802: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,3]<stderr>:2023-05-17 14:54:29.750151: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,5]<stderr>:2023-05-17 14:54:29.750152: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,3]<stderr>:2023-05-17 14:54:29.750356: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,5]<stderr>:2023-05-17 14:54:29.750355: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,3]<stderr>:2023-05-17 14:54:29.793664: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,5]<stderr>:2023-05-17 14:54:29.793664: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,7]<stderr>:WARNING:tensorflow:From AWS_DataPipping_TFMirroredStrategy.py:929: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
# [1,7]<stderr>:
# [1,3]<stderr>:WARNING:tensorflow:From AWS_DataPipping_TFMirroredStrategy.py:929: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
# [1,3]<stderr>:
# [1,6]<stderr>:WARNING:tensorflow:From AWS_DataPipping_TFMirroredStrategy.py:929: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
# [1,6]<stderr>:
# [1,2]<stderr>:WARNING:tensorflow:From AWS_DataPipping_TFMirroredStrategy.py:929: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
# [1,2]<stderr>:
# [1,0]<stderr>:WARNING:tensorflow:From AWS_DataPipping_TFMirroredStrategy.py:929: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
# [1,0]<stderr>:
# [1,1]<stderr>:WARNING:tensorflow:From AWS_DataPipping_TFMirroredStrategy.py:929: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
# [1,1]<stderr>:
# [1,5]<stderr>:WARNING:tensorflow:From AWS_DataPipping_TFMirroredStrategy.py:929: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
# [1,5]<stderr>:
# [1,4]<stderr>:WARNING:tensorflow:From AWS_DataPipping_TFMirroredStrategy.py:929: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
# [1,4]<stderr>:
# 2023-05-17 14:54:41,135 sagemaker-training-toolkit ERROR    ExecuteUserScriptError:
# [1,3]<stderr>:2023-05-17 14:54:35.736025: W tensorflow/core/framework/dataset.cc:446] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,4]<stderr>:2023-05-17 14:54:35.739031: W tensorflow/core/framework/dataset.cc:446] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# Command "mpirun --host algo-1:8 -np 8 --allow-run-as-root --display-map --tag-output -mca btl_tcp_if_include eth0 -mca oob_tcp_if_include eth0 -mca plm_rsh_no_tree_spawn 1 -bind-to none -map-by slot -mca pml ob1 -mca btl ^openib -mca orte_abort_on_non_zero_status 1 -mca btl_vader_single_copy_mechanism none -x NCCL_MIN_NRINGS=4 -x NCCL_SOCKET_IFNAME=eth0 -x NCCL_DEBUG=INFO -x LD_LIBRARY_PATH -x PATH -x LD_PRELOAD=/usr/local/lib/python3.7/site-packages/gethostname.cpython-37m-x86_64-linux-gnu.so -verbose -x OMPI_MCA_btl_vader_single_copy_mechanism=none -x SM_HOSTS -x SM_NETWORK_INTERFACE_NAME -x SM_HPS -x SM_USER_ENTRY_POINT -x SM_FRAMEWORK_PARAMS -x SM_RESOURCE_CONFIG -x SM_INPUT_DATA_CONFIG -x SM_OUTPUT_DATA_DIR -x SM_CHANNELS -x SM_CURRENT_HOST -x SM_MODULE_NAME -x SM_LOG_LEVEL -x SM_FRAMEWORK_MODULE -x SM_INPUT_DIR -x SM_INPUT_CONFIG_DIR -x SM_OUTPUT_DIR -x SM_NUM_CPUS -x SM_NUM_GPUS -x SM_MODEL_DIR -x SM_MODULE_DIR -x SM_TRAINING_ENV -x SM_USER_ARGS -x SM_OUTPUT_INTERMEDIATE_DIR -x SM_CHANNEL_TRAIN -x SM_HP_DOWNLOAD_RAW_DATA -x SM_HP_EPOCHS -x SM_HP_INPUT_DIST_MODE -x SM_HP_MODEL_DIR -x SM_HP_SHARDS_ON_INPUT -x SM_HP_TRAIN_DIST_MODE -x PYTHONPATH /usr/local/bin/python3.7 -m mpi4py AWS_DataPipping_TFMirroredStrategy.py --download_raw_data 1 --epochs 3 --input_dist_mode Pipe --model_dir /opt/ml/model --shards_on_input 120 --train_dist_mode MPI"
# [1,7]<stderr>:2023-05-17 14:54:35.742832: W tensorflow/core/framework/dataset.cc:446] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,1]<stderr>:2023-05-17 14:54:29.630212: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,1]<stderr>:2023-05-17 14:54:29.630455: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,0]<stderr>:2023-05-17 14:54:29.641890: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,5]<stderr>:2023-05-17 14:54:35.752003: W tensorflow/core/framework/dataset.cc:446] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,6]<stderr>:2023-05-17 14:54:35.753449: W tensorflow/core/framework/dataset.cc:446] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,2]<stderr>:2023-05-17 14:54:35.779036: W tensorflow/core/framework/dataset.cc:446] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,4]<stderr>:2023-05-17 14:54:29.641890: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,1]<stderr>:2023-05-17 14:54:35.845648: W tensorflow/core/framework/dataset.cc:446] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,6]<stderr>:2023-05-17 14:54:29.641890: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,0]<stderr>:2023-05-17 14:54:29.642095: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,4]<stderr>:2023-05-17 14:54:29.642096: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,6]<stderr>:2023-05-17 14:54:29.642098: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,2]<stderr>:2023-05-17 14:54:29.656149: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,2]<stderr>:2023-05-17 14:54:29.656341: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,7]<stderr>:2023-05-17 14:54:29.663799: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,7]<stderr>:2023-05-17 14:54:29.663957: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,1]<stderr>:2023-05-17 14:54:29.675012: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,0]<stderr>:2023-05-17 14:54:36.709803: W tensorflow/core/framework/dataset.cc:446] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,4]<stderr>:2023-05-17 14:54:29.685470: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,6]<stderr>:2023-05-17 14:54:29.685904: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,0]<stderr>:2023-05-17 14:54:29.687362: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,2]<stderr>:2023-05-17 14:54:29.701129: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,7]<stderr>:2023-05-17 14:54:29.705802: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,3]<stderr>:2023-05-17 14:54:29.750151: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,5]<stderr>:2023-05-17 14:54:29.750152: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,3]<stderr>:2023-05-17 14:54:29.750356: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,5]<stderr>:2023-05-17 14:54:29.750355: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,3]<stderr>:2023-05-17 14:54:29.793664: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,6]<stderr>:Traceback (most recent call last):
# [1,6]<stderr>:  File "/usr/local/lib/python3.7/runpy.py", line 193, in _run_module_as_main
# [1,6]<stderr>:    "__main__", mod_spec)
# [1,6]<stderr>:  File "/usr/local/lib/python3.7/runpy.py", line 85, in _run_code
# [1,6]<stderr>:    exec(code, run_globals)
# [1,6]<stderr>:  File "/usr/local/lib/python3.7/site-packages/mpi4py/__main__.py", line 7, in <module>
# [1,5]<stderr>:2023-05-17 14:54:29.793664: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,6]<stderr>:    main()
# [1,6]<stderr>:  File "/usr/local/lib/python3.7/site-packages/mpi4py/run.py", line 196, in main
# [1,6]<stderr>:    run_command_line(args)
# [1,7]<stderr>:WARNING:tensorflow:From AWS_DataPipping_TFMirroredStrategy.py:929: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
# [1,7]<stderr>:
# [1,6]<stderr>:  File "/usr/local/lib/python3.7/site-packages/mpi4py/run.py", line 47, in run_command_line
# [1,3]<stderr>:WARNING:tensorflow:From AWS_DataPipping_TFMirroredStrategy.py:929: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
# [1,3]<stderr>:
# [1,6]<stderr>:WARNING:tensorflow:From AWS_DataPipping_TFMirroredStrategy.py:929: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
# [1,6]<stderr>:
# [1,2]<stderr>:WARNING:tensorflow:From AWS_DataPipping_TFMirroredStrategy.py:929: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
# [1,2]<stderr>:
# [1,0]<stderr>:WARNING:tensorflow:From AWS_DataPipping_TFMirroredStrategy.py:929: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
# [1,0]<stderr>:
# [1,1]<stderr>:WARNING:tensorflow:From AWS_DataPipping_TFMirroredStrategy.py:929: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
# [1,1]<stderr>:
# [1,5]<stderr>:WARNING:tensorflow:From AWS_DataPipping_TFMirroredStrategy.py:929: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
# [1,5]<stderr>:
# [1,4]<stderr>:WARNING:tensorflow:From AWS_DataPipping_TFMirroredStrategy.py:929: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
# [1,4]<stderr>:
# [1,3]<stderr>:2023-05-17 14:54:35.736025: W tensorflow/core/framework/dataset.cc:446] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,6]<stderr>:    run_path(sys.argv[0], run_name='__main__')
# [1,6]<stderr>:  File "/usr/local/lib/python3.7/runpy.py", line 263, in run_path
# [1,6]<stderr>:    pkg_name=pkg_name, script_name=fname)
# [1,6]<stderr>:  File "/usr/local/lib/python3.7/runpy.py", line 96, in _run_module_code
# [1,6]<stderr>:    mod_name, mod_spec, pkg_name, script_name)
# [1,6]<stderr>:  File "/usr/local/lib/python3.7/runpy.py", line 85, in _run_code
# [1,6]<stderr>:    exec(code, run_globals)
# [1,6]<stderr>:  File "AWS_DataPipping_TFMirroredStrategy.py", line 1111, in <module>
# [1,5]<stderr>:Traceback (most recent call last):
# [1,5]<stderr>:  File "/usr/local/lib/python3.7/runpy.py", line 193, in _run_module_as_main
# [1,6]<stderr>:    callbacks = callbacks)
# [1,4]<stderr>:2023-05-17 14:54:35.739031: W tensorflow/core/framework/dataset.cc:446] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,7]<stderr>:2023-05-17 14:54:35.742832: W tensorflow/core/framework/dataset.cc:446] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,5]<stderr>:2023-05-17 14:54:35.752003: W tensorflow/core/framework/dataset.cc:446] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,6]<stderr>:2023-05-17 14:54:35.753449: W tensorflow/core/framework/dataset.cc:446] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,2]<stderr>:2023-05-17 14:54:35.779036: W tensorflow/core/framework/dataset.cc:446] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,1]<stderr>:2023-05-17 14:54:35.845648: W tensorflow/core/framework/dataset.cc:446] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,0]<stderr>:2023-05-17 14:54:36.709803: W tensorflow/core/framework/dataset.cc:446] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,6]<stderr>:Traceback (most recent call last):
# [1,6]<stderr>:  File "/usr/local/lib/python3.7/runpy.py", line 193, in _run_module_as_main
# [1,6]<stderr>:    "__main__", mod_spec)
# [1,6]<stderr>:  File "/usr/local/lib/python3.7/runpy.py", line 85, in _run_code
# [1,6]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py", line 109, in _method_wrapper
# [1,6]<stderr>:    exec(code, run_globals)
# [1,6]<stderr>:  File "/usr/local/lib/python3.7/site-packages/mpi4py/__main__.py", line 7, in <module>
# [1,6]<stderr>:    main()
# [1,6]<stderr>:  File "/usr/local/lib/python3.7/site-packages/mpi4py/run.py", line 196, in main
# [1,6]<stderr>:    run_command_line(args)
# [1,6]<stderr>:    return method(self, *args, **kwargs)
# [1,6]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py", line 1126, in fit
# [1,5]<stderr>:    "__main__", mod_spec)
# [1,6]<stderr>:  File "/usr/local/lib/python3.7/site-packages/mpi4py/run.py", line 47, in run_command_line
# [1,5]<stderr>:  File "/usr/local/lib/python3.7/runpy.py", line 85, in _run_code
# [1,6]<stderr>:    run_path(sys.argv[0], run_name='__main__')
# [1,5]<stderr>:    exec(code, run_globals)
# [1,6]<stderr>:  File "/usr/local/lib/python3.7/runpy.py", line 263, in run_path
# [1,6]<stderr>:    pkg_name=pkg_name, script_name=fname)
# [1,6]<stderr>:  File "/usr/local/lib/python3.7/runpy.py", line 96, in _run_module_code
# [1,6]<stderr>:    mod_name, mod_spec, pkg_name, script_name)
# [1,6]<stderr>:  File "/usr/local/lib/python3.7/runpy.py", line 85, in _run_code
# [1,5]<stderr>:  File "/usr/local/lib/python3.7/site-packages/mpi4py/__main__.py", line 7, in <module>
# [1,6]<stderr>:    exec(code, run_globals)
# [1,6]<stderr>:  File "AWS_DataPipping_TFMirroredStrategy.py", line 1111, in <module>
# [1,5]<stderr>:Traceback (most recent call last):
# [1,5]<stderr>:  File "/usr/local/lib/python3.7/runpy.py", line 193, in _run_module_as_main
# [1,6]<stderr>:    callbacks = callbacks)
# [1,6]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py", line 109, in _method_wrapper
# [1,6]<stderr>:    return method(self, *args, **kwargs)
# [1,5]<stderr>:    main()
# [1,6]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py", line 1126, in fit
# [1,5]<stderr>:  File "/usr/local/lib/python3.7/site-packages/mpi4py/run.py", line 196, in main
# [1,5]<stderr>:    "__main__", mod_spec)
# [1,5]<stderr>:  File "/usr/local/lib/python3.7/runpy.py", line 85, in _run_code
# [1,5]<stderr>:    exec(code, run_globals)
# [1,5]<stderr>:  File "/usr/local/lib/python3.7/site-packages/mpi4py/__main__.py", line 7, in <module>
# [1,5]<stderr>:    main()
# [1,5]<stderr>:  File "/usr/local/lib/python3.7/site-packages/mpi4py/run.py", line 196, in main
# [1,5]<stderr>:    run_command_line(args)
# [1,5]<stderr>:  File "/usr/local/lib/python3.7/site-packages/mpi4py/run.py", line 47, in run_command_line
# [1,5]<stderr>:    run_command_line(args)
# [1,5]<stderr>:  File "/usr/local/lib/python3.7/site-packages/mpi4py/run.py", line 47, in run_command_line
# [1,6]<stderr>:    tmp_logs = train_function(iterator)
# [1,6]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py", line 780, in __call__
# [1,5]<stderr>:    run_path(sys.argv[0], run_name='__main__')
# [1,5]<stderr>:  File "/usr/local/lib/python3.7/runpy.py", line 263, in run_path
# [1,5]<stderr>:    pkg_name=pkg_name, script_name=fname)
# [1,5]<stderr>:  File "/usr/local/lib/python3.7/runpy.py", line 96, in _run_module_code
# [1,6]<stderr>:    result = self._call(*args, **kwds)
# [1,6]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py", line 840, in _call
# [1,5]<stderr>:    mod_name, mod_spec, pkg_name, script_name)
# [1,5]<stderr>:  File "/usr/local/lib/python3.7/runpy.py", line 85, in _run_code
# [1,5]<stderr>:    exec(code, run_globals)
# [1,5]<stderr>:  File "AWS_DataPipping_TFMirroredStrategy.py", line 1111, in <module>
# [1,6]<stderr>:    return self._stateless_fn(*args, **kwds)
# ...
# [1,1]<stderr>:    result = self._call(*args, **kwds)
# [1,1]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py", line 840, in _call
# [1,7]<stderr>:    callbacks = callbacks)
# [1,1]<stderr>:#011 [[node IteratorGetNext (defined at AWS_DataPipping_TFMirroredStrategy.py:1111) ]]
# [1,1]<stderr>:#011 [[IteratorGetNext/_4]]
# [1,7]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py", line 109, in _method_wrapper
# [1,2]<stderr>:    callbacks = callbacks)
# [1,2]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py", line 109, in _method_wrapper
# [1,7]<stderr>:    return method(self, *args, **kwargs)
# [1,7]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py", line 1126, in fit
# [1,1]<stderr>:    return self._stateless_fn(*args, **kwds)
# [1,1]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 2829, in __call__
# [1,2]<stderr>:    return method(self, *args, **kwargs)
# [1,1]<stderr>:0 successful operations.
# [1,1]<stderr>:0 derived errors ignored. [Op:__inference_train_function_920]
# [1,2]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py", line 1126, in fit
# [1,1]<stderr>:
# [1,3]<stderr>:    return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
# [1,1]<stderr>:Function call stack:
# [1,3]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 1848, in _filtered_call
# [1,1]<stderr>:train_function -> train_function
# [1,7]<stderr>:    tmp_logs = train_function(iterator)
# [1,1]<stderr>:
# [1,7]<stderr>:    cancellation_manager=cancellation_manager)
# [1,7]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 1924, in _call_flat
# [1,2]<stderr>:    cancellation_manager=cancellation_manager)
# [1,2]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 1924, in _call_flat
# [1,7]<stderr>:    ctx, args, cancellation_manager=cancellation_manager))
# [1,7]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 550, in call
# [1,2]<stderr>:    ctx, args, cancellation_manager=cancellation_manager))
# [1,2]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 550, in call
# [1,7]<stderr>:    ctx=ctx)
# [1,7]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/execute.py", line 60, in quick_execute
# [1,7]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py", line 780, in __call__
# [1,2]<stderr>:    tmp_logs = train_function(iterator)
# [1,2]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py", line 780, in __call__
# [1,7]<stderr>:    result = self._call(*args, **kwds)
# [1,7]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py", line 840, in _call
# [1,3]<stderr>:    cancellation_manager=cancellation_manager)
# [1,3]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 1924, in _call_flat
# [1,2]<stderr>:    result = self._call(*args, **kwds)
# [1,2]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py", line 840, in _call
# [1,1]<stderr>:    return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
# [1,1]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 1848, in _filtered_call
# [1,7]<stderr>:    return self._stateless_fn(*args, **kwds)
# [1,7]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 2829, in __call__
# [1,2]<stderr>:    return self._stateless_fn(*args, **kwds)
# [1,2]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 2829, in __call__
# [1,3]<stderr>:    ctx, args, cancellation_manager=cancellation_manager))
# [1,3]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 550, in call
# [1,1]<stderr>:    cancellation_manager=cancellation_manager)
# [1,1]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 1924, in _call_flat
# [1,3]<stderr>:    ctx=ctx)
# [1,3]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/execute.py", line 60, in quick_execute
# [1,3]<stderr>:    inputs, attrs, num_outputs)
# [1,2]<stderr>:    ctx=ctx)
# [1,3]<stderr>:tensorflow.python.framework.errors_impl.InternalError: 2 root error(s) found.
# [1,3]<stderr>:  (0) Internal:  CRC check on header failed.
# [1,3]<stderr>:#011 [[node IteratorGetNext (defined at AWS_DataPipping_TFMirroredStrategy.py:1111) ]]
# [1,3]<stderr>:  (1) Internal:  CRC check on header failed.
# [1,3]<stderr>:#011 [[node IteratorGetNext (defined at AWS_DataPipping_TFMirroredStrategy.py:1111) ]]
# [1,2]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/execute.py", line 60, in quick_execute
# [1,3]<stderr>:#011 [[IteratorGetNext/_4]]
# [1,7]<stderr>:    inputs, attrs, num_outputs)
# [1,3]<stderr>:0 successful operations.
# [1,3]<stderr>:0 derived errors ignored. [Op:__inference_train_function_920]
# [1,3]<stderr>:
# [1,3]<stderr>:Function call stack:
# [1,3]<stderr>:train_function -> train_function
# [1,3]<stderr>:
# [1,7]<stderr>:    return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
# [1,7]<stderr>:tensorflow.python.framework.errors_impl.InternalError[1,7]<stderr>:: 2 root error(s) found.
# [1,7]<stderr>:  (0) Internal:  CRC check on header failed.
# [1,7]<stderr>:#011 [[node IteratorGetNext (defined at AWS_DataPipping_TFMirroredStrategy.py:1111) ]]
# [1,7]<stderr>:  (1) Internal:  CRC check on header failed.
# [1,7]<stderr>:#011 [[node IteratorGetNext (defined at AWS_DataPipping_TFMirroredStrategy.py:1111) ]]
# [1,7]<stderr>:#011 [[IteratorGetNext/_2]]
# [1,7]<stderr>:0 successful operations.
# [1,7]<stderr>:0 derived errors ignored. [Op:__inference_train_function_920]
# [1,7]<stderr>:
# [1,7]<stderr>:Function call stack:
# [1,7]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 1848, in _filtered_call
# [1,2]<stderr>:    return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
# [1,2]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 1848, in _filtered_call
# [1,1]<stderr>:    ctx, args, cancellation_manager=cancellation_manager))
# [1,1]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 550, in call
# [1,1]<stderr>:    ctx=ctx)
# [1,1]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/execute.py", line 60, in quick_execute
# [1,1]<stderr>:    inputs, attrs, num_outputs)[1,1]<stderr>:
# [1,1]<stderr>:tensorflow.python.framework.errors_impl[1,1]<stderr>:.InternalError: 2 root error(s) found.
# [1,1]<stderr>:  (0) Internal:  CRC check on header failed.
# [1,1]<stderr>:#011 [[node IteratorGetNext (defined at AWS_DataPipping_TFMirroredStrategy.py:1111) ]]
# [1,7]<stderr>:train_function -> train_function
# [1,7]<stderr>:
# [1,2]<stderr>:    inputs, attrs, num_outputs)
# [1,2]<stderr>:tensorflow.python.framework.errors_impl.InternalError: [1,2]<stderr>:2 root error(s) found.
# [1,2]<stderr>:  (0) Internal:  CRC check on header failed.
# [1,1]<stderr>:  (1) Internal:  CRC check on header failed.
# [1,1]<stderr>:#011 [[node IteratorGetNext (defined at AWS_DataPipping_TFMirroredStrategy.py:1111) ]]
# [1,1]<stderr>:#011 [[IteratorGetNext/_4]]
# [1,1]<stderr>:0 successful operations.
# [1,1]<stderr>:0 derived errors ignored. [Op:__inference_train_function_920]
# [1,1]<stderr>:
# [1,1]<stderr>:Function call stack:
# [1,1]<stderr>:train_function -> train_function
# [1,1]<stderr>:
# [1,7]<stderr>:    cancellation_manager=cancellation_manager)
# [1,7]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 1924, in _call_flat
# [1,2]<stderr>:    cancellation_manager=cancellation_manager)
# [1,2]<stderr>:#011 [[node IteratorGetNext (defined at AWS_DataPipping_TFMirroredStrategy.py:1111) ]]
# [1,2]<stderr>:  (1) Internal:  CRC check on header failed.
# [1,2]<stderr>:#011 [[node IteratorGetNext (defined at AWS_DataPipping_TFMirroredStrategy.py:1111) ]]
# [1,2]<stderr>:#011 [[IteratorGetNext/_2]]
# [1,2]<stderr>:0 successful operations.
# [1,2]<stderr>:0 derived errors ignored. [Op:__inference_train_function_920]
# [1,2]<stderr>:
# [1,2]<stderr>:Function call stack:
# [1,2]<stderr>:train_function -> train_function
# [1,2]<stderr>:
# --------------------------------------------------------------------------
# Primary job  terminated normally, but 1 process returned
# a non-zero exit code. Per user-direction, the job has been aborted.
# --------------------------------------------------------------------------
# [1,2]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 1924, in _call_flat
# [1,7]<stderr>:    ctx, args, cancellation_manager=cancellation_manager))
# [1,7]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 550, in call
# [1,2]<stderr>:    ctx, args, cancellation_manager=cancellation_manager))
# [1,2]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 550, in call
# [1,7]<stderr>:    ctx=ctx)
# [1,7]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/execute.py", line 60, in quick_execute
# [1,2]<stderr>:    ctx=ctx)
# --------------------------------------------------------------------------
# mpirun.real detected that one or more processes exited with non-zero status, thus causing
# the job to be terminated. The first process to do so was:
#   Process name: [[51068,1],7]
#   Exit code:    1
# --------------------------------------------------------------------------
# [1,2]<stderr>:  File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/execute.py", line 60, in quick_execute
# [1,7]<stderr>:    inputs, attrs, num_outputs)
# [1,7]<stderr>:tensorflow.python.framework.errors_impl.InternalError[1,7]<stderr>:: 2 root error(s) found.
# [1,7]<stderr>:  (0) Internal:  CRC check on header failed.
# [1,7]<stderr>:#011 [[node IteratorGetNext (defined at AWS_DataPipping_TFMirroredStrategy.py:1111) ]]
# [1,7]<stderr>:  (1) Internal:  CRC check on header failed.
# [1,7]<stderr>:#011 [[node IteratorGetNext (defined at AWS_DataPipping_TFMirroredStrategy.py:1111) ]]
# [1,7]<stderr>:#011 [[IteratorGetNext/_2]]
# [1,7]<stderr>:0 successful operations.
# [1,7]<stderr>:0 derived errors ignored. [Op:__inference_train_function_920]
# [1,7]<stderr>:
# [1,7]<stderr>:Function call stack:
# [1,7]<stderr>:train_function -> train_function
# [1,7]<stderr>:
# [1,2]<stderr>:    inputs, attrs, num_outputs)
# [1,2]<stderr>:tensorflow.python.framework.errors_impl.InternalError: [1,2]<stderr>:2 root error(s) found.
# [1,2]<stderr>:  (0) Internal:  CRC check on header failed.
# [1,2]<stderr>:#011 [[node IteratorGetNext (defined at AWS_DataPipping_TFMirroredStrategy.py:1111) ]]
# [1,2]<stderr>:  (1) Internal:  CRC check on header failed.
# [1,2]<stderr>:#011 [[node IteratorGetNext (defined at AWS_DataPipping_TFMirroredStrategy.py:1111) ]]
# [1,2]<stderr>:#011 [[IteratorGetNext/_2]]
# [1,2]<stderr>:0 successful operations.
# [1,2]<stderr>:0 derived errors ignored. [Op:__inference_train_function_920]
# [1,2]<stderr>:
# [1,2]<stderr>:Function call stack:
# [1,2]<stderr>:train_function -> train_function
# [1,2]<stderr>:
# --------------------------------------------------------------------------
# Primary job  terminated normally, but 1 process returned
# a non-zero exit code. Per user-direction, the job has been aborted.
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# mpirun.real detected that one or more processes exited with non-zero status, thus causing
# the job to be terminated. The first process to do so was:
#   Process name: [[51068,1],7]
#   Exit code:    1
# --------------------------------------------------------------------------
#
# 2023-05-17 14:54:59 Failed - Training job failed
# ---------------------------------------------------------------------------
# UnexpectedStatusException                 Traceback (most recent call last)
# <ipython-input-3-ecdf9669e887> in <module>
#      51                     #"validation": f"s3://{bucket_name}/data/validation",}
#      52
# ---> 53 tf_estimator.fit(s3_data_channels)
#      54
#      55 ##########################################################################################################################
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/workflow/pipeline_context.py in wrapper(*args, **kwargs)
#     282             return _StepArguments(retrieve_caller_name(self_instance), run_func, *args, **kwargs)
#     283
# --> 284         return run_func(*args, **kwargs)
#     285
#     286     return wrapper
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name, experiment_config)
#    1196         self.jobs.append(self.latest_training_job)
#    1197         if wait:
# -> 1198             self.latest_training_job.wait(logs=logs)
#    1199
#    1200     def _compilation_job_name(self):
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/estimator.py in wait(self, logs)
#    2342         # If logs are requested, call logs_for_jobs.
#    2343         if logs != "None":
# -> 2344             self.sagemaker_session.logs_for_job(self.job_name, wait=True, log_type=logs)
#    2345         else:
#    2346             self.sagemaker_session.wait_for_job(self.job_name)
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/session.py in logs_for_job(self, job_name, wait, poll, log_type, timeout)
#    4628             exceptions.UnexpectedStatusException: If waiting and the training job fails.
#    4629         """
# -> 4630         _logs_for_job(self.boto_session, job_name, wait, poll, log_type, timeout)
#    4631
#    4632     def logs_for_processing_job(self, job_name, wait=False, poll=10):
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/session.py in _logs_for_job(boto_session, job_name, wait, poll, log_type, timeout)
#    6490
#    6491     if wait:
# -> 6492         _check_job_status(job_name, description, "TrainingJobStatus")
#    6493         if dot:
#    6494             print()
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/session.py in _check_job_status(job, desc, status_key_name)
#    6546             message=message,
#    6547             allowed_statuses=["Completed", "Stopped"],
# -> 6548             actual_status=status,
#    6549         )
#    6550
#
# UnexpectedStatusException: Error for Training job tensorflow-training-2023-05-17-14-49-51-884: Failed. Reason: AlgorithmError: ExecuteUserScriptError:
# Command "mpirun --host algo-1:8 -np 8 --allow-run-as-root --display-map --tag-output -mca btl_tcp_if_include eth0 -mca oob_tcp_if_include eth0 -mca plm_rsh_no_tree_spawn 1 -bind-to none -map-by slot -mca pml ob1 -mca btl ^openib -mca orte_abort_on_non_zero_status 1 -mca btl_vader_single_copy_mechanism none -x NCCL_MIN_NRINGS=4 -x NCCL_SOCKET_IFNAME=eth0 -x NCCL_DEBUG=INFO -x LD_LIBRARY_PATH -x PATH -x LD_PRELOAD=/usr/local/lib/python3.7/site-packages/gethostname.cpython-37m-x86_64-linux-gnu.so -verbose -x OMPI_MCA_btl_vader_single_copy_mechanism=none -x SM_HOSTS -x SM_NETWORK_INTERFACE_NAME -x SM_HPS -x SM_USER_ENTRY_POINT -x SM_FRAMEWORK_PARAMS -x SM_RESOURCE_CONFIG -x SM_INPUT_DATA_CONFIG -x SM_OUTPUT_DATA_DIR -x SM_CHANNELS -x SM_CURRENT_HOST -x SM_MODULE_NAME -x SM_LOG_LEVEL -x SM_FRAMEWORK_MODULE -x SM_INPUT_DIR -x SM_INPUT_CONFIG_DIR -x SM_OUTPUT_DIR -x SM_NUM_CPUS -x SM_NUM_GPUS -x SM_MODEL_DIR -x SM_MODULE_DIR -x SM_TRAINING_ENV -x SM_USER_ARGS -x SM_OUTPUT_INTE

# %%
(60000//512), (60000- 512*117)/64

# %%
###############################
########### SMD ###############
###############################

8 GPU, 4 shards on input, FastFile, FullyReplicated, 1 Instance
OVERWRITTEN with MPI but comperable with the rest of SMD

8 GPU, 120 shards on input, FastFile, FullyReplicated, 1 Instance
[1,0]<stdout>:Epoch 3, Loss: 0.0011306742671877146, # Train Accuracy: 0.0, Test Accuracy: 0.0
[1,0]<stdout>:Training Time 193.52111554145813

8 GPU, 120 shards on input, FastFile, ShardedByS3Key, 1 Instance
[1,0]<stdout>:Epoch 3, Loss: 0.0017849248833954334, # Train Accuracy: 0.0, Test Accuracy: 0.0
[1,0]<stdout>:Training Time 195.88474798202515


8 GPU, 120 shards on input, Pipe, FullyReplicated, 1 Instance
FAILED with error: "tensorflow.python.framework.errors_impl.InternalError: CRC check on header failed. [Op:IteratorGetNext]"


# MULTIPLE INSTANCES DID NOT WORK - ??!?!?!??!
8 GPU x 2 Instances, 120 shards on input, FastFile, FullyReplicated
???

8 GPU x 2 Instances, 120 shards on input, FastFile, ShardedByS3Key, 2 Instances
???

# %%
###############################
########### MPI ###############
###############################

8 GPU, 4 shards on input, FastFile, FullyReplicated, 1 Instance
[1,0]<stdout>:  1/117 - 0s - loss: 0.4659 - accuracy: 0.7917 - batch: 1.0000
[1,0]<stdout>:RUN TIME 62.51244115829468

8 GPU, 120 shards on input, FastFile, FullyReplicated, 1 Instance
[1,0]<stdout>:  1/117 - 0s - loss: 0.0704 - accuracy: 0.9896 - batch: 1.0000
[1,0]<stdout>:RUN TIME 62.72578692436218

8 GPU, 120 shards on input, FastFile, ShardedByS3Key, 1 Instance
[1,0]<stdout>:  1/117 - 0s - loss: 0.0031 - accuracy: 1.0000 - batch: 1.0000
[1,0]<stdout>:RUN TIME 62.7252471446991


# KINDA WORKS BUT IT IS SLOW?!?!?!?!?!?
8 GPU x 2 Instances, 120 shards on input, FastFile, FullyReplicated, Batch 64
[1,0]<stdout>: 1/58 - 0s - loss: 0.3692 - accuracy: 0.8734 - batch: 1.0000
[1,0]<stdout>:RUN TIME 113.62855267524719

8 GPU x 2 Instances, 120 shards on input, FastFile, ShardedByS3Key, Batch 64
[1,0]<stdout>:30/58 - 45s - loss: 170.1098 - accuracy: 0.1032 - batch: 0.0000e+00
[1,0]<stdout>:RUN TIME 65.18587517738342


8 GPU, 120 shards on input, Pipe, ShardedByS3Key, 1 Instance
FAILED with error: "Internal:  CRC check on header failed."

possibly beacuse only 1 GPU is visible!!!
"""
[1,7]<stdout>:7 Num GPUs: 1 [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
[1,7]<stdout>:hvd.rank 7 7
[1,3]<stdout>:3 Num GPUs: 1 [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
[1,3]<stdout>:hvd.rank 3 3
[1,6]<stdout>:6 Num GPUs: 1 [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
[1,6]<stdout>:hvd.rank 6[1,6]<stdout>: 6
[1,2]<stdout>:2 Num GPUs: 1 [1,2]<stdout>:[PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
[1,2]<stdout>:hvd.rank 2[1,2]<stdout>: 2
[1,0]<stdout>:0 Num GPUs: 1 [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
[1,0]<stdout>:hvd.rank 0 0
[1,1]<stdout>:1 Num GPUs: 1 [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
[1,1]<stdout>:hvd.rank 1 1
[1,5]<stdout>:5 Num GPUs: 1 [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
[1,5]<stdout>:hvd.rank 5 5
[1,4]<stdout>:4 Num GPUs: 1 [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
[1,4]<stdout>:hvd.rank 4 4
"""
